# %% [markdown]
# <a href="https://colab.research.google.com/github/5hyfilm/deeplearning-ca/blob/main/multi_squeezenet_nb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Check GPU

# %%
# !nvidia-smi
# Out:
# Tue Jul 20 06:57:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   65C    P8    11W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras import models
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Activation, Flatten, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import regularizers

from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight, compute_sample_weight, compute_class_weight
from sklearn.metrics import balanced_accuracy_score, classification_report, confusion_matrix

import pandas as pd
import numpy as np
import os
import shutil
import math
import itertools
from PIL import Image
from matplotlib import pyplot as plt
import seaborn as sns
import json
import cv2

# %%
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# # Data Preparation

# %%
# !git clone https://github.com/5HYFILM-DATA/deeplearning-ca-dataset-2
# Out:
# Cloning into 'deeplearning-ca-dataset-2'...
# remote: Enumerating objects: 1804, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 1804 (delta 0), reused 2 (delta 0), pack-reused 1801
# Receiving objects: 100% (1804/1804), 1.01 GiB | 39.25 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Checking out files: 100% (1959/1959), done.

# %%
model_name = 'multi_squeezenet'
base = '/content/deeplearning-ca-dataset-2'
base_data = os.path.join(base, 'data_for_train')
base_output = os.path.join(model_name + '_output', model_name + '_result')

dataset_types = ['train', 'test', 'validate']
categories = ['cancer', 'normal', 'pmd']

# %%
if not os.path.exists(base_data):
    os.makedirs(base_data, exist_ok=True)
if not os.path.exists(base_output):
    os.makedirs(base_output, exist_ok=True)

# %%
datasets = {dataset_type:[] for dataset_type in dataset_types}
for category in categories:
    df = pd.read_json(os.path.join(base, 'dataset_{}_augment.json'.format(category)))
    for dataset_type in dataset_types:
        datasets[dataset_type].append(df[df['type']==dataset_type])

for dataset_type in datasets:
    df = pd.concat(datasets[dataset_type])
    df['file_name'] = base+"/image/"+df['category']+"/"+df['file_name']
    datasets[dataset_type] = df

# %%
train_aug = ImageDataGenerator(rescale=1./255)

val_aug = ImageDataGenerator(rescale=1./255)

test_aug = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ## Hyperparameters

# %%
IMG_WIDTH = 224
IMG_HEIGHT = 224
EPOCHS = 100
BATCH_SIZE = 32
LR = 1e-5 # Learning rate

# %%
train_generator = train_aug.flow_from_dataframe(datasets['train'],
                                                x_col='file_name',
                                                y_col='category',
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True,
                                                class_mode='sparse') 

val_generator = val_aug.flow_from_dataframe(datasets['validate'],
                                                x_col='file_name',
                                                y_col='category',
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True,
                                                class_mode='sparse') 

test_generator = test_aug.flow_from_dataframe(datasets['test'],
                                                x_col='file_name',
                                                y_col='category',
                                                target_size=(IMG_WIDTH, IMG_HEIGHT), 
                                                batch_size=1, 
                                                shuffle=False,
                                                class_mode='sparse')
# Out:
# Found 1360 validated image filenames belonging to 3 classes.
# Found 196 validated image filenames belonging to 3 classes.
# Found 392 validated image filenames belonging to 3 classes.

# %%
NUM_CLASSES = len(train_generator.class_indices)

# %% [markdown]
# # Model

# %% [markdown]
# ## Build Model

# %%
def fire(x, squeeze, expand):
  y  = tf.keras.layers.Conv2D(filters=squeeze, kernel_size=1, activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01))(x)
  y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
  y1 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=1, activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01))(y) 
  y1 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y1)
  y3 = tf.keras.layers.Conv2D(filters=expand//2, kernel_size=3, activation='relu', padding='same', kernel_regularizer=regularizers.l2(0.01))(y)
  y3 = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y3)
  return tf.keras.layers.concatenate([y1, y3])

def fire_module(squeeze, expand):
  return lambda x: fire(x, squeeze, expand)

# %%
bnmomemtum=0.9

# %%
x = tf.keras.layers.Input(shape=[IMG_HEIGHT, IMG_WIDTH, 3]) # input is 224x224 pixels RGB

y = tf.keras.layers.Conv2D(kernel_size=3, filters=32, padding='same', use_bias=True, activation='relu')(x)
y = tf.keras.layers.BatchNormalization(momentum=bnmomemtum)(y)
y = fire_module(24, 48)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(48, 96)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(64, 128)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(48, 96)(y)
y = tf.keras.layers.MaxPooling2D(pool_size=2)(y)
y = fire_module(24, 48)(y)
y = tf.keras.layers.GlobalAveragePooling2D()(y)
y = tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')(y)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/layers/normalization.py:534: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model = tf.keras.Model(x, y)

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 32) 128         conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 24) 792         batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 24) 96          conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 24) 600         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 24) 5208        batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 24) 96          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 24) 96          conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 224, 224, 48) 0           batch_normalization_2[0][0]
#                                                                  batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 48) 0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 48) 2352        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 48) 192         conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 48) 2352        batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 48) 20784       batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 48) 192         conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 48) 192         conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 112, 112, 96) 0           batch_normalization_5[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 96)   0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 56, 56, 64)   6208        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 56, 56, 64)   256         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 56, 56, 64)   4160        batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 56, 56, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 56, 56, 64)   256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 56, 56, 64)   256         conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 56, 56, 128)  0           batch_normalization_8[0][0]
#                                                                  batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 128)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 48)   6192        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 28, 28, 48)   192         conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 48)   2352        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 48)   20784       batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 28, 28, 48)   192         conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 28, 28, 48)   192         conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 28, 28, 96)   0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 96)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 24)   2328        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 24)   96          conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 24)   600         batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 24)   5208        batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 24)   96          conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 14, 14, 24)   96          conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 14, 14, 48)   0           batch_normalization_14[0][0]
#                                                                  batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 48)           0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 3)            147         global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 120,515
# Trainable params: 119,203
# Non-trainable params: 1,312
# __________________________________________________________________________________________________

# %% [markdown]
# ## Compile

# %%
model.compile(optimizer=Adam(LR), 
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# %% [markdown]
# ## Callbacks

# %%
model_path = os.path.join(base_output, "{}_model.h5".format(model_name))

# %%
early_stop = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=10, verbose=0, mode='max')

model_checkpoint = ModelCheckpoint(filepath=model_path, save_best_only=True, monitor='val_loss', mode='min')

reduce_lr_rate = ReduceLROnPlateau(monitor='val_loss', factor=0.3, min_lr=1e-7, patience=10, verbose=1, min_delta=1e-4, mode='min')

# %% [markdown]
# ## Training

# %%
history = model.fit(train_generator,
                    validation_data=val_generator,
                    epochs=EPOCHS,
                    callbacks=[early_stop, model_checkpoint, reduce_lr_rate],
                    verbose=1)
# Out:
# Epoch 1/100
# 43/43 [==============================] - ETA: 0s - batch: 21.0000 - size: 31.6279 - loss: 7.8173 - sparse_categorical_accuracy: 0.3654
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
# 43/43 [==============================] - 118s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.8173 - sparse_categorical_accuracy: 0.3654 - val_loss: 7.8848 - val_sparse_categorical_accuracy: 0.3214 - lr: 1.0000e-05
# Epoch 2/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.7415 - sparse_categorical_accuracy: 0.4757 - val_loss: 7.7192 - val_sparse_categorical_accuracy: 0.5408 - lr: 1.0000e-05
# Epoch 3/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.6783 - sparse_categorical_accuracy: 0.5331 - val_loss: 7.6753 - val_sparse_categorical_accuracy: 0.5306 - lr: 1.0000e-05
# Epoch 4/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.6305 - sparse_categorical_accuracy: 0.5721 - val_loss: 7.6279 - val_sparse_categorical_accuracy: 0.5612 - lr: 1.0000e-05
# Epoch 5/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.5867 - sparse_categorical_accuracy: 0.6022 - val_loss: 7.5938 - val_sparse_categorical_accuracy: 0.5867 - lr: 1.0000e-05
# Epoch 6/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.5398 - sparse_categorical_accuracy: 0.6294 - val_loss: 7.5637 - val_sparse_categorical_accuracy: 0.6020 - lr: 1.0000e-05
# Epoch 7/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.5042 - sparse_categorical_accuracy: 0.6507 - val_loss: 7.5275 - val_sparse_categorical_accuracy: 0.5969 - lr: 1.0000e-05
# Epoch 8/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.4756 - sparse_categorical_accuracy: 0.6654 - val_loss: 7.4946 - val_sparse_categorical_accuracy: 0.6122 - lr: 1.0000e-05
# Epoch 9/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.4422 - sparse_categorical_accuracy: 0.6684 - val_loss: 7.4680 - val_sparse_categorical_accuracy: 0.6327 - lr: 1.0000e-05
# Epoch 10/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.4074 - sparse_categorical_accuracy: 0.6721 - val_loss: 7.4414 - val_sparse_categorical_accuracy: 0.6480 - lr: 1.0000e-05
# Epoch 11/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.3781 - sparse_categorical_accuracy: 0.6809 - val_loss: 7.4327 - val_sparse_categorical_accuracy: 0.6480 - lr: 1.0000e-05
# Epoch 12/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.3488 - sparse_categorical_accuracy: 0.7132 - val_loss: 7.4015 - val_sparse_categorical_accuracy: 0.6684 - lr: 1.0000e-05
# Epoch 13/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.3261 - sparse_categorical_accuracy: 0.7162 - val_loss: 7.3805 - val_sparse_categorical_accuracy: 0.6888 - lr: 1.0000e-05
# Epoch 14/100
# 43/43 [==============================] - 88s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.2881 - sparse_categorical_accuracy: 0.7221 - val_loss: 7.3562 - val_sparse_categorical_accuracy: 0.6735 - lr: 1.0000e-05
# Epoch 15/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.2595 - sparse_categorical_accuracy: 0.7301 - val_loss: 7.3242 - val_sparse_categorical_accuracy: 0.6990 - lr: 1.0000e-05
# Epoch 16/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.2352 - sparse_categorical_accuracy: 0.7324 - val_loss: 7.2890 - val_sparse_categorical_accuracy: 0.7398 - lr: 1.0000e-05
# Epoch 17/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.2077 - sparse_categorical_accuracy: 0.7485 - val_loss: 7.2618 - val_sparse_categorical_accuracy: 0.7704 - lr: 1.0000e-05
# Epoch 18/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.1868 - sparse_categorical_accuracy: 0.7434 - val_loss: 7.2481 - val_sparse_categorical_accuracy: 0.7602 - lr: 1.0000e-05
# Epoch 19/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.1614 - sparse_categorical_accuracy: 0.7647 - val_loss: 7.2089 - val_sparse_categorical_accuracy: 0.7755 - lr: 1.0000e-05
# Epoch 20/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.1316 - sparse_categorical_accuracy: 0.7632 - val_loss: 7.2057 - val_sparse_categorical_accuracy: 0.7959 - lr: 1.0000e-05
# Epoch 21/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.1104 - sparse_categorical_accuracy: 0.7691 - val_loss: 7.1629 - val_sparse_categorical_accuracy: 0.7908 - lr: 1.0000e-05
# Epoch 22/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.0954 - sparse_categorical_accuracy: 0.7721 - val_loss: 7.1420 - val_sparse_categorical_accuracy: 0.8163 - lr: 1.0000e-05
# Epoch 23/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.0717 - sparse_categorical_accuracy: 0.7765 - val_loss: 7.1414 - val_sparse_categorical_accuracy: 0.8163 - lr: 1.0000e-05
# Epoch 24/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.0444 - sparse_categorical_accuracy: 0.7890 - val_loss: 7.1029 - val_sparse_categorical_accuracy: 0.8061 - lr: 1.0000e-05
# Epoch 25/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.0221 - sparse_categorical_accuracy: 0.7882 - val_loss: 7.0979 - val_sparse_categorical_accuracy: 0.8265 - lr: 1.0000e-05
# Epoch 26/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 7.0018 - sparse_categorical_accuracy: 0.7897 - val_loss: 6.9689 - val_sparse_categorical_accuracy: 0.8265 - lr: 1.0000e-05
# Epoch 27/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.9749 - sparse_categorical_accuracy: 0.8015 - val_loss: 6.9451 - val_sparse_categorical_accuracy: 0.8316 - lr: 1.0000e-05
# Epoch 28/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.9540 - sparse_categorical_accuracy: 0.8169 - val_loss: 6.9292 - val_sparse_categorical_accuracy: 0.8214 - lr: 1.0000e-05
# Epoch 29/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.9198 - sparse_categorical_accuracy: 0.8206 - val_loss: 6.9009 - val_sparse_categorical_accuracy: 0.8418 - lr: 1.0000e-05
# Epoch 30/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.9057 - sparse_categorical_accuracy: 0.8096 - val_loss: 6.8815 - val_sparse_categorical_accuracy: 0.8418 - lr: 1.0000e-05
# Epoch 31/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.9026 - sparse_categorical_accuracy: 0.7993 - val_loss: 6.8565 - val_sparse_categorical_accuracy: 0.8469 - lr: 1.0000e-05
# Epoch 32/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.8780 - sparse_categorical_accuracy: 0.8147 - val_loss: 6.8277 - val_sparse_categorical_accuracy: 0.8622 - lr: 1.0000e-05
# Epoch 33/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.8433 - sparse_categorical_accuracy: 0.8272 - val_loss: 6.8236 - val_sparse_categorical_accuracy: 0.8469 - lr: 1.0000e-05
# Epoch 34/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.8156 - sparse_categorical_accuracy: 0.8390 - val_loss: 6.7975 - val_sparse_categorical_accuracy: 0.8622 - lr: 1.0000e-05
# Epoch 35/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.8051 - sparse_categorical_accuracy: 0.8257 - val_loss: 6.7806 - val_sparse_categorical_accuracy: 0.8724 - lr: 1.0000e-05
# Epoch 36/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.7817 - sparse_categorical_accuracy: 0.8382 - val_loss: 6.7639 - val_sparse_categorical_accuracy: 0.8724 - lr: 1.0000e-05
# Epoch 37/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.7730 - sparse_categorical_accuracy: 0.8265 - val_loss: 6.7392 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 38/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.7601 - sparse_categorical_accuracy: 0.8338 - val_loss: 6.7208 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 39/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.7275 - sparse_categorical_accuracy: 0.8397 - val_loss: 6.7074 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 40/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6968 - sparse_categorical_accuracy: 0.8581 - val_loss: 6.7119 - val_sparse_categorical_accuracy: 0.8724 - lr: 1.0000e-05
# Epoch 41/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6901 - sparse_categorical_accuracy: 0.8426 - val_loss: 6.6869 - val_sparse_categorical_accuracy: 0.8827 - lr: 1.0000e-05
# Epoch 42/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6712 - sparse_categorical_accuracy: 0.8529 - val_loss: 6.6678 - val_sparse_categorical_accuracy: 0.8827 - lr: 1.0000e-05
# Epoch 43/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6464 - sparse_categorical_accuracy: 0.8500 - val_loss: 6.6385 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 44/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6385 - sparse_categorical_accuracy: 0.8544 - val_loss: 6.6342 - val_sparse_categorical_accuracy: 0.8827 - lr: 1.0000e-05
# Epoch 45/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.6246 - sparse_categorical_accuracy: 0.8500 - val_loss: 6.6045 - val_sparse_categorical_accuracy: 0.8827 - lr: 1.0000e-05
# Epoch 46/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5957 - sparse_categorical_accuracy: 0.8596 - val_loss: 6.6031 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 47/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5779 - sparse_categorical_accuracy: 0.8566 - val_loss: 6.5794 - val_sparse_categorical_accuracy: 0.8929 - lr: 1.0000e-05
# Epoch 48/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5688 - sparse_categorical_accuracy: 0.8603 - val_loss: 6.5708 - val_sparse_categorical_accuracy: 0.8878 - lr: 1.0000e-05
# Epoch 49/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5473 - sparse_categorical_accuracy: 0.8574 - val_loss: 6.5615 - val_sparse_categorical_accuracy: 0.8878 - lr: 1.0000e-05
# Epoch 50/100
# 43/43 [==============================] - 85s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5382 - sparse_categorical_accuracy: 0.8632 - val_loss: 6.4898 - val_sparse_categorical_accuracy: 0.8929 - lr: 1.0000e-05
# Epoch 51/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.5097 - sparse_categorical_accuracy: 0.8757 - val_loss: 6.4801 - val_sparse_categorical_accuracy: 0.8878 - lr: 1.0000e-05
# Epoch 52/100
# 43/43 [==============================] - 87s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4960 - sparse_categorical_accuracy: 0.8640 - val_loss: 6.4580 - val_sparse_categorical_accuracy: 0.8929 - lr: 1.0000e-05
# Epoch 53/100
# 43/43 [==============================] - 88s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4731 - sparse_categorical_accuracy: 0.8801 - val_loss: 6.4407 - val_sparse_categorical_accuracy: 0.8776 - lr: 1.0000e-05
# Epoch 54/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4627 - sparse_categorical_accuracy: 0.8816 - val_loss: 6.4245 - val_sparse_categorical_accuracy: 0.8878 - lr: 1.0000e-05
# Epoch 55/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4509 - sparse_categorical_accuracy: 0.8743 - val_loss: 6.4101 - val_sparse_categorical_accuracy: 0.8878 - lr: 1.0000e-05
# Epoch 56/100
# 43/43 [==============================] - 86s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4276 - sparse_categorical_accuracy: 0.8809 - val_loss: 6.4008 - val_sparse_categorical_accuracy: 0.8827 - lr: 1.0000e-05
# Epoch 57/100
# 43/43 [==============================] - 84s 2s/step - batch: 21.0000 - size: 31.6279 - loss: 6.4167 - sparse_categorical_accuracy: 0.8750 - val_loss: 6.3763 - val_sparse_categorical_accuracy: 0.8929 - lr: 1.0000e-05

# %% [markdown]
# # Training Graph

# %% [markdown]
# ## Accuracy

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history['sparse_categorical_accuracy'])
plt.plot(history.history['val_sparse_categorical_accuracy'])
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('accuracy graph {}'.format(model_name))
plt.grid()
plt.savefig(os.path.join(base_output, '{}_accuracy_graph'.format(model_name)))
plt.show()

# %% [markdown]
# ## Loss

# %%
plt.figure(figsize=(12, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.title('loss graph {}'.format(model_name))
plt.grid()
plt.savefig(os.path.join(base_output, '{}_loss_graph'.format(model_name)))
plt.show()

# %% [markdown]
# # Evaluation

# %%
test_model = tf.keras.models.load_model(model_path)

# %%
num_test_files = len(test_generator.filenames)

# %%
test_generator.reset()

# %% [markdown]
# ## Confusion Matrix

# %%
test_labels = test_generator.classes
predictions = test_model.predict(test_generator, steps=num_test_files//test_generator.batch_size)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2426: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))

# %% [markdown]
# ### Without Normalize

# %%
plt.title('{} confusionmatrix w/o normalize'.format(model_name))
df_cm = pd.DataFrame(cm, categories, categories)
sns.set(font_scale=1.4)
fig = sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='g', cmap="Blues")
fig.figure.savefig(os.path.join(base_output, '{}_confusionmatrix_wo_normalize'.format(model_name)))

# %% [markdown]
# ### With Normalize

# %%
cm = confusion_matrix(test_labels, predictions.argmax(axis=1))
cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# %%
plt.title('{} confusionmatrix w/ normalize'.format(model_name))
df_cm = pd.DataFrame(cm, categories, categories)
sns.set(font_scale=1.4)
fig = sns.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='g', cmap="Blues")
fig.figure.savefig(os.path.join(base_output, '{}_confusionmatrix_w_normalize'.format(model_name)))

# %% [markdown]
# ## Classification Report

# %%
y_pred = np.argmax(predictions, axis=1)
print('Confusion Matrix {}'.format(model_name))
print(confusion_matrix(test_labels, y_pred))
print('Classification Report {}'.format(model_name))
print(classification_report(test_labels, y_pred, target_names=categories))
# Out:
# Confusion Matrix multi_squeezenet
# [[104  16  24]
#  [  2 111   7]
#  [ 17  11 100]]
# Classification Report multi_squeezenet
#               precision    recall  f1-score   support
#
#       cancer       0.85      0.72      0.78       144
#       normal       0.80      0.93      0.86       120
#          pmd       0.76      0.78      0.77       128
#
#     accuracy                           0.80       392
#    macro avg       0.80      0.81      0.80       392
# weighted avg       0.81      0.80      0.80       392

# %% [markdown]
# ## TP FP FN TN

# %%
cm_2 = confusion_matrix(test_labels, y_pred)

# %% [markdown]
# ### TP

# %%
TruePositive= np.diag(cm_2)

# %%
print(TruePositive)
sumTruePositive = sum(TruePositive)
print('Sum of True Positive: ', sumTruePositive)
# Out:
# [104 111 100]
# Sum of True Positive:  315

# %% [markdown]
# ### FP

# %%
FalsePositive = []
for i in range(NUM_CLASSES):
    FalsePositive.append(sum(cm_2[:,i]) - cm_2[i,i])

# %%
print(FalsePositive)
sumFalsePositive = sum(FalsePositive)
print('Sum of False Positive: ', sumFalsePositive)
# Out:
# [19, 27, 31]
# Sum of False Positive:  77

# %% [markdown]
# ### FN

# %%
FalseNegative = []
for i in range(NUM_CLASSES):
    FalseNegative.append(sum(cm_2[i,:]) - cm_2[i,i])

# %%
print(FalseNegative)
sumFalseNegative = sum(FalseNegative)
print('Sum of False Negative: ', sumFalseNegative)
# Out:
# [40, 9, 28]
# Sum of False Negative:  77

# %% [markdown]
# ### TN

# %%
TrueNegative = []
for i in range(NUM_CLASSES):
    temp = np.delete(cm_2, i, 0)   # delete ith row
    temp = np.delete(temp, i, 1)  # delete ith column
    TrueNegative.append(sum(sum(temp)))

# %%
print(TrueNegative)
sumTrueNegative = sum(TrueNegative)
print('Sum of True Negative: ', sumTrueNegative)
# Out:
# [229, 245, 233]
# Sum of True Negative:  707

# %% [markdown]
# ### Check TP + FP + FN + TN = Test set

# %%
l = len(test_labels)
for i in range(NUM_CLASSES):
    print(TruePositive[i] + FalsePositive[i] + FalseNegative[i] + TrueNegative[i] == l)
# Out:
# True
# True
# True

# %% [markdown]
# ## PYCM

# %%
# !pip3 install pycm==3.0
# Out:
# Collecting pycm==3.0
#   Downloading pycm-3.0-py2.py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 569 kB/s
# Collecting art>=1.8
#   Downloading art-5.2-py2.py3-none-any.whl (571 kB)
#      |████████████████████████████████| 571 kB 15.8 MB/s
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from pycm==3.0) (1.19.5)
# Installing collected packages: art, pycm
# Successfully installed art-5.2 pycm-3.0

# %%
from pycm import *

# %%
test_labels = test_generator.classes

# %%
py_cm = ConfusionMatrix(actual_vector=test_labels, predict_vector=y_pred)

# %%
py_cm.classes
# Out:
# [0, 1, 2]

# %%
py_cm.table
# Out:
# {0: {0: 104, 1: 16, 2: 24}, 1: {0: 2, 1: 111, 2: 7}, 2: {0: 17, 1: 11, 2: 100}}

# %% [markdown]
# ### Sensitivity

# %%
AV_Sens = (py_cm.TPR[0] + py_cm.TPR[1] + py_cm.TPR[2])/len(py_cm.TPR)

# %%
print('Sensitivity of', categories[0], py_cm.TPR[0])
print('Sensitivity of', categories[1], py_cm.TPR[1])
print('Sensitivity of', categories[2], py_cm.TPR[2])
print('Average Sensitivity: ', AV_Sens)
# Out:
# Sensitivity of cancer 0.7222222222222222
# Sensitivity of normal 0.925
# Sensitivity of pmd 0.78125
# Average Sensitivity:  0.8094907407407407

# %% [markdown]
# ### Specificity

# %%
AV_Spec = (py_cm.TNR[0] + py_cm.TNR[1] + py_cm.TNR[2])/len(py_cm.TNR)

# %%
print('Specificity of', categories[0], py_cm.TNR[0])
print('Specificity of', categories[1], py_cm.TNR[1])
print('Specificity of', categories[2], py_cm.TNR[2])
print('Average Specificity: ', AV_Spec)
# Out:
# Specificity of cancer 0.9233870967741935
# Specificity of normal 0.9007352941176471
# Specificity of pmd 0.8825757575757576
# Average Specificity:  0.9022327161558662

# %% [markdown]
# ## Curve

# %% [markdown]
# ### Receiver Operating Characteristic curve
# from: https://www.analyticsvidhya.com/blog/2020/06/auc-roc-curve-machine-learning/

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
fpr = {}
tpr = {}
thresh ={}
roc_auc_list = []

plt.figure(figsize=(12, 8))
for i in range(NUM_CLASSES):    
    fpr[i], tpr[i], thresh[i] = roc_curve(test_generator.classes, predictions[:,i], pos_label=i)
    roc_auc = auc(fpr[i], tpr[i])
    roc_auc_list.append(roc_auc)
    plt.plot(fpr[i], tpr[i], lw=2, label='{} (area = %0.2f)'.format(categories[i]) % roc_auc)
plt.title('{} Receiver Operating Characteristic curve'.format(model_name))
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.savefig(os.path.join(base_output, '{}_roc_curve'.format(model_name)))

av_roc_auc = sum(roc_auc_list) / len(roc_auc_list)
print('Average Receiver Operating Characteristic AUC: ', av_roc_auc)
# Out:
# Average Receiver Operating Characteristic AUC:  0.931959533467183

# %% [markdown]
# ### Precision-Recall curve
# from: https://stackoverflow.com/a/56092736/9956949

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score

# %%
precision = {}
recall = {}
pr_auc_list = []

plt.figure(figsize=(12, 8))
for i in range(NUM_CLASSES):
    precision[i], recall[i], _ = precision_recall_curve(test_generator.classes, predictions[:,i], pos_label=i)
    pr_auc = auc(recall[i], precision[i])
    pr_auc_list.append(pr_auc)
    plt.plot(recall[i], precision[i], lw=2, label='{} (area = %0.2f)'.format(categories[i]) % pr_auc)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.legend(loc="best")
plt.title("{} Precision-Recall curve".format(model_name))
plt.savefig(os.path.join(base_output, '{}_pr_curve'.format(model_name)))

av_pr_auc = sum(pr_auc_list) / len(pr_auc_list)
print('Average Precision-Recall AUC: ', av_pr_auc)
# Out:
# Average Precision-Recall AUC:  0.8956575280146198

# %% [markdown]
# ## Grad-CAM

# %%
last_conv2d = 'conv2d_15'

# %%
def load_image(path, preprocess=True):
    """Load and preprocess image."""
    x = image.load_img(path, target_size=(IMG_HEIGHT, IMG_WIDTH))
    if preprocess:
        x = image.img_to_array(x)
        x = np.expand_dims(x, axis=0)
        x = preprocess_input(x)
    return x

# %%
def normalize(x):
    """Utility function to normalize a tensor by its L2 norm"""
    return (x + 1e-10) / (K.sqrt(K.mean(K.square(x))) + 1e-10)

# %%
def deprocess_image(x):
    """Same normalization as in:
    https://github.com/fchollet/keras/blob/master/examples/conv_filter_visualization.py
    """
    x = x.copy()
    if np.ndim(x) > 3:
        x = np.squeeze(x)
    # normalize tensor: center on 0., ensure std is 0.1
    x -= x.mean()
    x /= (x.std() + 1e-5)
    x *= 0.1
    # clip to [0, 1]
    x += 0.5
    x = np.clip(x, 0, 1)
    # convert to RGB array
    x *= 255
    if tf.keras.backend.image_data_format() == 'th':
        x = x.transpose((1, 2, 0))
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
def decode_predictions(preds, top=3, class_list_path='/content/deeplearning-ca-dataset-2/multi_index.json'):
    if len(preds.shape) != 2 or preds.shape[1] != 3:
        raise ValueError('`decode_predictions` expects '
                     'a batch of predictions '
                     '(i.e. a 2D array of shape (samples, 1000)). '
                     'Found array with shape: ' + str(preds.shape))
    CLASS_INDEX = json.load(open(class_list_path))
    results = []
    for pred in preds:
        top_indices = pred.argsort()[-top:][::-1]
        result = [tuple(CLASS_INDEX[str(i)]) + (pred[i],) for i in top_indices]
        result.sort(key=lambda x: x[2], reverse=True)
        results.append(result)
    return results

# %%
def guided_backprop(input_model, images, layer_name):
    """Guided Backpropagation method for visualizing input saliency."""
    input_imgs = input_model.input
    layer_output = input_model.get_layer(layer_name).output
    grads = tf.gradients(layer_output, input_imgs)[0]
    backprop_fn = K.function([input_imgs, K.learning_phase()], [grads])
    grads_val = backprop_fn([images, 0])[0]
    return grads_val

# %%
def grad_cam(input_model, image, cls, layer_name):
    """GradCAM method for visualizing input saliency."""
    y_c = input_model.output[0, cls]
    conv_output = input_model.get_layer(layer_name).output
    grads = tf.gradients(y_c, conv_output)[0]
    # Normalize if necessary
    # grads = normalize(grads)
    gradient_function = K.function([input_model.input], [conv_output, grads])
    output, grads_val = gradient_function([image])
    output, grads_val = output[0, :], grads_val[0, :, :, :]
    weights = np.mean(grads_val, axis=(0, 1))
    cam = np.dot(output, weights)
    # Process CAM
    cam = cv2.resize(cam, (IMG_WIDTH, IMG_HEIGHT), cv2.INTER_LINEAR)
    cam = np.maximum(cam, 0)
    cam = cam / cam.max()
    return cam

# %%
def grad_cam_batch(input_model, images, classes, layer_name):
    """GradCAM method for visualizing input saliency.
    Same as grad_cam but processes multiple images in one run."""
    loss = tf.gather_nd(input_model.output, np.dstack([range(images.shape[0]), classes])[0])
    layer_output = input_model.get_layer(layer_name).output
    grads = tf.gradients(loss, layer_output)[0]
    gradient_fn = K.function([input_model.input, K.learning_phase()], [layer_output, grads])
    conv_output, grads_val = gradient_fn([images, 0])    
    weights = np.mean(grads_val, axis=(1, 2))
    cams = np.einsum('ijkl,il->ijk', conv_output, weights)
    # Process CAMs
    new_cams = np.empty((images.shape[0], IMG_HEIGHT, IMG_WIDTH))
    for i in range(new_cams.shape[0]):
        cam_i = cams[i] - cams[i].mean()
        cam_i = (cam_i + 1e-10) / (np.linalg.norm(cam_i, 2) + 1e-10)
        new_cams[i] = cv2.resize(cam_i, (IMG_WIDTH, IMG_HEIGHT), cv2.INTER_LINEAR)
        new_cams[i] = np.maximum(new_cams[i], 0)
        new_cams[i] = new_cams[i] / new_cams[i].max()
    return new_cams

# %%
def compute_saliency(model, guided_model, img_path, layer_name=None, cls=-1, visualize=True, save=True):
    """Compute saliency using all three approaches.
        -layer_name: layer to compute gradients;
        -cls: class number to localize (-1 for most probable class).
    """
    preprocessed_input = load_image(img_path)
    predictions = model.predict(preprocessed_input)
    top_n = 5
    top = decode_predictions(predictions, top=top_n)[0]
    classes = np.argsort(predictions[0])[-top_n:][::-1]
    print('Model prediction:')
    for c, p in zip(classes, top):
        print('\t{:15s}\t({})\twith probability {:.3f}'.format(p[1], c, p[2]))
    if cls == -1:
        cls = np.argmax(predictions)
    class_name = decode_predictions(np.eye(1, 3, cls))[0][0][1]
    print("Explanation for '{}'".format(class_name))  
    gradcam = grad_cam(model, preprocessed_input, cls, layer_name)
    gb = guided_backprop(guided_model, preprocessed_input, layer_name)
    guided_gradcam = gb * gradcam[..., np.newaxis]
    if save:
        jetcam = cv2.applyColorMap(np.uint8(255 * gradcam), cv2.COLORMAP_JET)
        jetcam = (np.float32(jetcam) + load_image(img_path, preprocess=False)) / 2
        cv2.imwrite('gradcam_{}.jpg'.format(img_path), np.uint8(jetcam))
        cv2.imwrite('guided_backprop_{}.jpg'.format(img_path), deprocess_image(gb[0]))
        cv2.imwrite('guided_gradcam_{}.jpg'.format(img_path), deprocess_image(guided_gradcam[0]))
    if visualize:
        plt.figure(figsize=(15, 10))
        plt.subplot(131)
        plt.title('GradCAM of {}'.format(img_path))
        plt.axis('off')
        plt.imshow(load_image(img_path, preprocess=False))
        plt.imshow(gradcam, cmap='jet', alpha=0.5)
        plt.subplot(132)
        plt.title('Guided Backprop of {}'.format(img_path))
        plt.axis('off')
        plt.imshow(np.flip(deprocess_image(gb[0]), -1))
        plt.subplot(133)
        plt.title('Guided GradCAM of {}'.format(img_path))
        plt.axis('off')
        plt.imshow(np.flip(deprocess_image(guided_gradcam[0]), -1))
        plt.show()      
    return gradcam, gb, guided_gradcam

# %% [markdown]
# ### Cancer

# %%
cancer_img = '/content/deeplearning-ca-dataset-2/image/cancer/Cancer_A_4_U5QEvnm_augment2.jpg'
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, cancer_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	normal         	(1)	with probability 1.000
# 	cancer         	(0)	with probability 0.000
# 	pmd            	(2)	with probability 0.000
# Explanation for 'normal'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### Normal

# %%
normal_img = '/content/deeplearning-ca-dataset-2/image/normal/normal-0.jpg'
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, normal_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	cancer         	(0)	with probability 1.000
# 	pmd            	(2)	with probability 0.000
# 	normal         	(1)	with probability 0.000
# Explanation for 'cancer'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ### PMD

# %%
pmd_img = '/content/deeplearning-ca-dataset-2/image/pmd/PMD_A_3.jpg'
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, pmd_img, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	cancer         	(0)	with probability 1.000
# 	pmd            	(2)	with probability 0.000
# 	normal         	(1)	with probability 0.000
# Explanation for 'cancer'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:16: RuntimeWarning: invalid value encountered in true_divide
#   app.launch_new_instance()
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:452: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# /usr/local/lib/python3.7/dist-packages/matplotlib/image.py:464: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# <string>:6: UserWarning: Warning: converting a masked element to nan.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: UserWarning: Warning: converting a masked element to nan.
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Download Model

# %%
from google.colab import files

# %%
shutil.move(base_output, "/content/")
# Out:
# '/content/multi_squeezenet_result'

# %%
# !zip -r /content/multi_squeezenet_result.zip /content/multi_squeezenet_result
# Out:
#   adding: content/multi_squeezenet_result/ (stored 0%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_roc_curve.png (deflated 12%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_confusionmatrix_wo_normalize.png (deflated 8%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_accuracy_graph.png (deflated 7%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_model.h5 (deflated 23%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_pr_curve.png (deflated 7%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_loss_graph.png (deflated 7%)
#   adding: content/multi_squeezenet_result/multi_squeezenet_confusionmatrix_w_normalize.png (deflated 4%)

# %%
files.download('/content/multi_squeezenet_result.zip')
