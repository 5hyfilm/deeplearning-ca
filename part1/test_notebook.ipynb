# %% [markdown]
# <a href="https://colab.research.google.com/github/fxlmer/AJPom_cancer/blob/main/test_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fxlmer/AJPom_cancer
# Out:
# Cloning into 'AJPom_cancer'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 23 (delta 2), reused 0 (delta 0), pack-reused 17
# Unpacking objects: 100% (23/23), done.

# %%
# !git clone https://github.com/EvilPickle-PCSHSPT/AJPom_cancer_data
# Out:
# Cloning into 'AJPom_cancer_data'...
# remote: Enumerating objects: 1203, done.
# remote: Total 1203 (delta 0), reused 0 (delta 0), pack-reused 1203
# Receiving objects: 100% (1203/1203), 1.45 GiB | 42.84 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Checking out files: 100% (810/810), done.

# %%
import tensorflow as tf
from google.colab import files
from AJPom_cancer_utils import *

# %%
tf.compat.v1.disable_eager_execution()

# %%
test_model = tf.keras.models.load_model('/content/AJPom_cancer/AJPom_cancer_DenseNet121_model.h5')

# %%
# test_model.summary()

# %% [markdown]
# # Upload your test sample

# %%
uploaded = files.upload()

for fn in uploaded.keys():
  path = '/content/' + fn
# Out:
#      <input type="file" id="files-829b3997-499e-4888-bf65-f3b3ab3f97f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-829b3997-499e-4888-bf65-f3b3ab3f97f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Cancer_edit_A_27.jpg to Cancer_edit_A_27.jpg

# %% [markdown]
# # Grad-CAM

# %%
last_conv2d = 'conv5_block16_2_conv'

# %%
gradcam, gb, guided_gradcam = compute_saliency(test_model, test_model, path, layer_name=last_conv2d)
# Out:
# Model prediction:
# 	cancer         	(0)	with probability 0.985
# 	normal         	(1)	with probability 0.015
# Explanation for 'cancer'
